# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import os
import cv2
import shutil
from functions import rotate_image, crop_image, blur_image, change_color, adjust_color_balance
import random

# %%
df = pd.read_csv("./dataset/SB-FishDisease.csv")

# %%
df['target'].value_counts()
# Out:
# target
# disease    268
# healthy    155
# Name: count, dtype: int64

# %%
train_df, test_df = train_test_split(df, test_size=0.2, stratify=df['sickness'], random_state=42)

print("Träningsuppsättning:")
print(train_df['sickness'].value_counts())

print("\nTestuppsättning:")
print(test_df['sickness'].value_counts())
# Out:
# Träningsuppsättning:
# sickness
# healthy_fish                         113
# bacterial_gill disease                43
# fungal_diseases_saprolegniasis        37
# bacterial_diseases _aeromoniasis      37
# bacterial_red disease                 36
# viral_diseases_white_tail_disease     33
# parasitic_diseases                    28
# healthy_gills                         11
# Name: count, dtype: int64
#
# Testuppsättning:
# sickness
# healthy_fish                         28
# bacterial_gill disease               11
# bacterial_diseases _aeromoniasis     10
# fungal_diseases_saprolegniasis        9
# bacterial_red disease                 9
# viral_diseases_white_tail_disease     8
# parasitic_diseases                    7
# healthy_gills                         3
# Name: count, dtype: int64

# %%
train_df
# Out:
#                                                   path  \
# 119  ./dataset/SB-FishDisease/Bacterial Red disease...
# 225  ./dataset/SB-FishDisease/Healthy Fish\Healthy_...
# 56   ./dataset/SB-FishDisease/Bacterial gill diseas...
# 109  ./dataset/SB-FishDisease/Bacterial Red disease...
# 396  ./dataset/SB-FishDisease/Viral diseases White ...
# ..                                                 ...
# 162  ./dataset/SB-FishDisease/Fungal diseases Sapro...
# 340  ./dataset/SB-FishDisease/Healthy Gills\healthy...
# 156  ./dataset/SB-FishDisease/Fungal diseases Sapro...
# 408  ./dataset/SB-FishDisease/Viral diseases White ...
# 416  ./dataset/SB-FishDisease/Viral diseases White ...
#
#                               sickness   target
# 119              bacterial_red disease  disease
# 225                       healthy_fish  healthy
# 56              bacterial_gill disease  disease
# 109              bacterial_red disease  disease
# 396  viral_diseases_white_tail_disease  disease
# ..                                 ...      ...
# 162     fungal_diseases_saprolegniasis  disease
# 340                      healthy_gills  healthy
# 156     fungal_diseases_saprolegniasis  disease
# 408  viral_diseases_white_tail_disease  disease
# 416  viral_diseases_white_tail_disease  disease
#
# [338 rows x 3 columns]

# %%
def augment_and_save(image_path, output_folder, augmented_df, row, save_folder, data_label):
    # Load the original image
    original_image = cv2.imread(image_path)
    
    # Extract file name and extension
    file_name, file_extension = os.path.splitext(os.path.basename(image_path))
    
    # Augmentation functions with their corresponding parameters
    augmentation_functions = [
        (rotate_image, {'angle': 30}),
        # (crop_image, {}),
        (blur_image, {'k_size': 5}),
        (change_color, {'flag': cv2.COLOR_BGR2GRAY}),
        (adjust_color_balance, {'red_factor': 1.0, 'green_factor': 0.8, 'blue_factor': 0.8}),
    ]
    
    # Determine whether to save in train or val
    
    # Save the original image
    original_image_path = os.path.join(output_folder, save_folder, f'{file_name}_original{file_extension}')
    cv2.imwrite(original_image_path, original_image)
    augmented_images = []
    augmented_data = {
        'path': original_image_path,
        'sickness': row['sickness'],
        'target': row['target'],
        'data': data_label,  # Assuming all augmented images are for training
        }
    augmented_images.append(augmented_data)
    # Apply augmentation functions
    for idx, (aug_func, params) in enumerate(augmentation_functions):
        augmented_image = aug_func(original_image, **params)
        
        # Save augmented image
        augmented_image_path = os.path.join(output_folder, save_folder, f'{file_name}_augmented_{idx}{file_extension}')
        cv2.imwrite(augmented_image_path, augmented_image)
        augmented_data = {
        'path': augmented_image_path,
        'sickness': row['sickness'],
        'target': row['target'],
        'data': data_label,  # Assuming all augmented images are for training
        }
        augmented_images.append(augmented_data)
    augmented_df = pd.concat([augmented_df, pd.DataFrame(augmented_images)], ignore_index=True)
    return augmented_df

# %%
output_folder = './dataset/splitted_and_augmented_data'
os.makedirs(os.path.join(output_folder, 'train'), exist_ok=True)
os.makedirs(os.path.join(output_folder, 'test'), exist_ok=True)

# %%
augmented_df = pd.DataFrame(columns=['path', 'sickness', 'target', 'data'])
save_folder = 'train'

for index, row in train_df.iterrows():
    image_path = row['path']
    augmented_df = augment_and_save(image_path, output_folder, augmented_df, row, save_folder, data_label='train')

# %%
augmented_df
# Out:
#                                                    path  \
# 0     ./dataset/splitted_and_augmented_data\train\Ba...
# 1     ./dataset/splitted_and_augmented_data\train\Ba...
# 2     ./dataset/splitted_and_augmented_data\train\Ba...
# 3     ./dataset/splitted_and_augmented_data\train\Ba...
# 4     ./dataset/splitted_and_augmented_data\train\Ba...
# ...                                                 ...
# 1685  ./dataset/splitted_and_augmented_data\train\Vi...
# 1686  ./dataset/splitted_and_augmented_data\train\Vi...
# 1687  ./dataset/splitted_and_augmented_data\train\Vi...
# 1688  ./dataset/splitted_and_augmented_data\train\Vi...
# 1689  ./dataset/splitted_and_augmented_data\train\Vi...
#
#                                sickness   target   data
# 0                 bacterial_red disease  disease  train
# 1                 bacterial_red disease  disease  train
# 2                 bacterial_red disease  disease  train
# 3                 bacterial_red disease  disease  train
# 4                 bacterial_red disease  disease  train
# ...                                 ...      ...    ...
# 1685  viral_diseases_white_tail_disease  disease  train
# 1686  viral_diseases_white_tail_disease  disease  train
# 1687  viral_diseases_white_tail_disease  disease  train
# 1688  viral_diseases_white_tail_disease  disease  train
# 1689  viral_diseases_white_tail_disease  disease  train
#
# [1690 rows x 4 columns]

# %%
augmented_images = []
for index, row in test_df.iterrows():
    image_path = row['path']
        
    # Extract file name and extension
    file_name, file_extension = os.path.splitext(os.path.basename(image_path))

    # Determine the save folder
    save_folder = 'test'

    # Save the original image to the 'test' folder
    original_image_path = os.path.join(output_folder, save_folder, f'{file_name}_original{file_extension}')
    shutil.copyfile(image_path, original_image_path)
    augmented_data = {
        'path': original_image_path,
        'sickness': row['sickness'],
        'target': row['target'],
        'data': 'test',  # Assuming all augmented images are for training
        }
    augmented_images.append(augmented_data)
augmented_df = pd.concat([augmented_df, pd.DataFrame(augmented_images)], ignore_index=True)

# %%
output_csv_path = './dataset/splitted_and_augmented_data/augmented_data.csv'

# %%
augmented_df.to_csv(output_csv_path, index=False)
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
