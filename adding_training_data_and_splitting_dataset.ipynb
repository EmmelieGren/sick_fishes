# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import os
import cv2
import shutil
from functions import rotate_image, crop_image, blur_image, change_color, adjust_color_balance, flip_image, rotate_and_resize
import random

# %%
df = pd.read_csv("./dataset/cropped_images/augmented_data.csv")

# %%
df['target'].value_counts()
# Out:
# target
# disease    213
# healthy    134
# Name: count, dtype: int64

# %%
train_df, test_df = train_test_split(df, test_size=0.2, stratify=df['sickness'], random_state=42)

print("Träningsuppsättning:")
print(train_df['sickness'].value_counts())

print("\nTestuppsättning:")
print(test_df['sickness'].value_counts())
# Out:
# Träningsuppsättning:
# sickness
# healthy_fish                         107
# bacterial_diseases _aeromoniasis      37
# fungal_diseases_saprolegniasis        37
# bacterial_red disease                 35
# viral_diseases_white_tail_disease     33
# parasitic_diseases                    28
# Name: count, dtype: int64
#
# Testuppsättning:
# sickness
# healthy_fish                         27
# bacterial_diseases _aeromoniasis     10
# bacterial_red disease                 9
# fungal_diseases_saprolegniasis        9
# viral_diseases_white_tail_disease     8
# parasitic_diseases                    7
# Name: count, dtype: int64

# %%
train_df
# Out:
#      Unnamed: 0                                               path  \
# 30           30  ./dataset/cropped_images/cropped_Bacterial_dis...
# 221         225  ./dataset/cropped_images/cropped_Healthy_Fish_...
# 297         305  ./dataset/cropped_images/cropped_Parasitic_dis...
# 329         337  ./dataset/cropped_images/cropped_Viral_disease...
# 251         256  ./dataset/cropped_images/cropped_Healthy_Fish_...
# ..          ...                                                ...
# 37           37  ./dataset/cropped_images/cropped_Bacterial_dis...
# 281         289  ./dataset/cropped_images/cropped_Parasitic_dis...
# 95           96  ./dataset/cropped_images/cropped_Fungal_diseas...
# 36           36  ./dataset/cropped_images/cropped_Bacterial_dis...
# 51           51  ./dataset/cropped_images/Bacterial_Red disease...
#
#                               sickness   target
# 30   bacterial_diseases _aeromoniasis   disease
# 221                       healthy_fish  healthy
# 297                 parasitic_diseases  disease
# 329  viral_diseases_white_tail_disease  disease
# 251                       healthy_fish  healthy
# ..                                 ...      ...
# 37   bacterial_diseases _aeromoniasis   disease
# 281                 parasitic_diseases  disease
# 95      fungal_diseases_saprolegniasis  disease
# 36   bacterial_diseases _aeromoniasis   disease
# 51               bacterial_red disease  disease
#
# [277 rows x 4 columns]

# %%
test_df
# Out:
#      Unnamed: 0                                               path  \
# 72           73  ./dataset/cropped_images/cropped_Bacterial_Red...
# 321         329  ./dataset/cropped_images/cropped_Viral_disease...
# 199         202  ./dataset/cropped_images/cropped_Healthy_Fish_...
# 286         294  ./dataset/cropped_images/cropped_Parasitic_dis...
# 115         116  ./dataset/cropped_images/cropped_Fungal_diseas...
# ..          ...                                                ...
# 28           28  ./dataset/cropped_images/cropped_Bacterial_dis...
# 270         278  ./dataset/cropped_images/cropped_healthy_fish_...
# 188         191  ./dataset/cropped_images/cropped_Healthy_Fish_...
# 74           75  ./dataset/cropped_images/cropped_Bacterial_Red...
# 213         217  ./dataset/cropped_images/cropped_Healthy_Fish_...
#
#                               sickness   target
# 72               bacterial_red disease  disease
# 321  viral_diseases_white_tail_disease  disease
# 199                       healthy_fish  healthy
# 286                 parasitic_diseases  disease
# 115     fungal_diseases_saprolegniasis  disease
# ..                                 ...      ...
# 28   bacterial_diseases _aeromoniasis   disease
# 270                       healthy_fish  healthy
# 188                       healthy_fish  healthy
# 74               bacterial_red disease  disease
# 213                       healthy_fish  healthy
#
# [70 rows x 4 columns]

# %%
def augment_and_save(image_path, output_folder, augmented_df, row, save_folder, data_label):
    original_image = cv2.imread(image_path)
    
    file_name, file_extension = os.path.splitext(os.path.basename(image_path))
    
    augmentation_functions = [
        (rotate_and_resize, {'angle': 30}),
        (rotate_and_resize, {'angle': 60}),
        (blur_image, {'k_size': 5}),
        (change_color, {'flag': cv2.COLOR_BGR2GRAY}),
        (adjust_color_balance, {'red_factor': 1.0, 'green_factor': 0.8, 'blue_factor': 0.8}),
    ]
    
    original_image_path = os.path.join(output_folder, save_folder, f'{file_name}_original{file_extension}')
    cv2.imwrite(original_image_path, original_image)
    
    augmented_images = []
    augmented_data = {
        'path': original_image_path,
        'sickness': row['sickness'],
        'target': row['target'],
        'data': data_label,
    }
    augmented_images.append(augmented_data)
    
    for idx, (aug_func, params) in enumerate(augmentation_functions):
        augmented_image = aug_func(original_image, **params)
        
        if 'rotate_and_resize' in aug_func.__name__.lower():
            augmented_image_path = os.path.join(output_folder, save_folder, f'{file_name}_augmented_{idx}{file_extension}')
            cv2.imwrite(augmented_image_path, augmented_image)
            augmented_data = {
                'path': augmented_image_path,
                'sickness': row['sickness'],
                'target': row['target'],
                'data': data_label,
            }
            augmented_images.append(augmented_data)
            
            augmented_image_path_bw = os.path.join(output_folder, save_folder, f'{file_name}_augmented_{idx}_bw{file_extension}')
            cv2.imwrite(augmented_image_path_bw, cv2.cvtColor(augmented_image, cv2.COLOR_BGR2GRAY))
            augmented_data_bw = {
                'path': augmented_image_path_bw,
                'sickness': row['sickness'],
                'target': row['target'],
                'data': data_label,
            }
            augmented_images.append(augmented_data_bw)
        else:
            augmented_image_path = os.path.join(output_folder, save_folder, f'{file_name}_augmented_{idx}{file_extension}')
            cv2.imwrite(augmented_image_path, augmented_image)
            augmented_data = {
                'path': augmented_image_path,
                'sickness': row['sickness'],
                'target': row['target'],
                'data': data_label,
            }
            augmented_images.append(augmented_data)
    
    augmented_df = pd.concat([augmented_df, pd.DataFrame(augmented_images)], ignore_index=True)
    return augmented_df

# %%
def augment_and_save(image_path, output_folder, augmented_df, row, save_folder, data_label):
    original_image = cv2.imread(image_path)
    
    file_name, file_extension = os.path.splitext(os.path.basename(image_path))
    
    augmentation_functions = [
        (rotate_and_resize, {'angle': 30}),
        (rotate_and_resize, {'angle': 60}),
        (rotate_and_resize, {'angle': -30}),
        (rotate_and_resize, {'angle': -60}),
        (blur_image, {'k_size': 5}),
        (change_color, {'flag': cv2.COLOR_BGR2GRAY}),
        (adjust_color_balance, {'red_factor': 1.0, 'green_factor': 0.8, 'blue_factor': 0.8}),
    ]
    
    # För varje originalbild
    for flip_flag in [False, True]:
        # Skapa en kopia av originalbilden
        current_image = original_image.copy()

        # Flippa bilden om det är nödvändigt
        if flip_flag:
            current_image = flip_image(current_image)

        original_image_path = os.path.join(output_folder, save_folder, f'{file_name}_{"flipped_" if flip_flag else ""}original{file_extension}')
        cv2.imwrite(original_image_path, current_image)

        augmented_images = []
        augmented_data = {
            'path': original_image_path,
            'sickness': row['sickness'],
            'target': row['target'],
            'data': data_label,
        }
        augmented_images.append(augmented_data)

        for idx, (aug_func, params) in enumerate(augmentation_functions):
            # Använd aktuell bild
            augmented_image = aug_func(current_image, **params)

            if 'rotate_and_resize' in aug_func.__name__.lower():
                augmented_image_path = os.path.join(output_folder, save_folder, f'{file_name}_{"flipped_" if flip_flag else ""}augmented_{idx}{file_extension}')
                cv2.imwrite(augmented_image_path, augmented_image)
                augmented_data = {
                    'path': augmented_image_path,
                    'sickness': row['sickness'],
                    'target': row['target'],
                    'data': data_label,
                }
                augmented_images.append(augmented_data)

                augmented_image_path_bw = os.path.join(output_folder, save_folder, f'{file_name}_{"flipped_" if flip_flag else ""}augmented_{idx}_bw{file_extension}')
                cv2.imwrite(augmented_image_path_bw, cv2.cvtColor(augmented_image, cv2.COLOR_BGR2GRAY))
                augmented_data_bw = {
                    'path': augmented_image_path_bw,
                    'sickness': row['sickness'],
                    'target': row['target'],
                    'data': data_label,
                }
                augmented_images.append(augmented_data_bw)
            else:
                augmented_image_path = os.path.join(output_folder, save_folder, f'{file_name}_{"flipped_" if flip_flag else ""}augmented_{idx}{file_extension}')
                cv2.imwrite(augmented_image_path, augmented_image)
                augmented_data = {
                    'path': augmented_image_path,
                    'sickness': row['sickness'],
                    'target': row['target'],
                    'data': data_label,
                }
                augmented_images.append(augmented_data)

        augmented_df = pd.concat([augmented_df, pd.DataFrame(augmented_images)], ignore_index=True)
    
    return augmented_df

# %%
output_folder = './dataset/more_cropped_splitted_and_augmented_data'
os.makedirs(os.path.join(output_folder, 'train'), exist_ok=True)
os.makedirs(os.path.join(output_folder, 'test'), exist_ok=True)

# %%
augmented_df = pd.DataFrame(columns=['path', 'sickness', 'target', 'data'])
save_folder = 'train'

for index, row in train_df.iterrows():
    image_path = row['path']
    augmented_df = augment_and_save(image_path, output_folder, augmented_df, row, save_folder, data_label='train')

# %%
augmented_df
# Out:
#                                                    path  \
# 0     ./dataset/more_cropped_splitted_and_augmented_...
# 1     ./dataset/more_cropped_splitted_and_augmented_...
# 2     ./dataset/more_cropped_splitted_and_augmented_...
# 3     ./dataset/more_cropped_splitted_and_augmented_...
# 4     ./dataset/more_cropped_splitted_and_augmented_...
# ...                                                 ...
# 6643  ./dataset/more_cropped_splitted_and_augmented_...
# 6644  ./dataset/more_cropped_splitted_and_augmented_...
# 6645  ./dataset/more_cropped_splitted_and_augmented_...
# 6646  ./dataset/more_cropped_splitted_and_augmented_...
# 6647  ./dataset/more_cropped_splitted_and_augmented_...
#
#                                sickness   target   data
# 0     bacterial_diseases _aeromoniasis   disease  train
# 1     bacterial_diseases _aeromoniasis   disease  train
# 2     bacterial_diseases _aeromoniasis   disease  train
# 3     bacterial_diseases _aeromoniasis   disease  train
# 4     bacterial_diseases _aeromoniasis   disease  train
# ...                                 ...      ...    ...
# 6643              bacterial_red disease  disease  train
# 6644              bacterial_red disease  disease  train
# 6645              bacterial_red disease  disease  train
# 6646              bacterial_red disease  disease  train
# 6647              bacterial_red disease  disease  train
#
# [6648 rows x 4 columns]

# %%
augmented_images = []
for index, row in test_df.iterrows():
    image_path = row['path']
        
    file_name, file_extension = os.path.splitext(os.path.basename(image_path))

    save_folder = 'test'

    original_image_path = os.path.join(output_folder, save_folder, f'{file_name}_original{file_extension}')
    shutil.copyfile(image_path, original_image_path)
    augmented_data = {
        'path': original_image_path,
        'sickness': row['sickness'],
        'target': row['target'],
        'data': 'test',
        }
    augmented_images.append(augmented_data)
augmented_df = pd.concat([augmented_df, pd.DataFrame(augmented_images)], ignore_index=True)

# %%
output_csv_path = './dataset/more_cropped_splitted_and_augmented_data/augmented_data.csv'

# %%
augmented_df.to_csv(output_csv_path, index=False)
